# %%
from kan import *

# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = KAN(width=[9,9,1], grid=5, k=3, seed=0,device=device)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('african_crises.csv')
# Select features and target variable
# Example: using 'inflation_annual_cpi' and 'exch_usd' as input features
# and 'banking_crisis' as the target (converted to numeric)
'''features = df[['year', 'systemic_crisis', 'domestic_debt_in_default', 'sovereign_external_debt_default', 'gdp_weighted_default', 
               'independence', 'currency_crises', 'inflation_annual_cpi', 'exch_usd']]'''
features = df[['year', 'systemic_crisis', 'domestic_debt_in_default', 'sovereign_external_debt_default', 'gdp_weighted_default', 
               'independence', 'currency_crises', 'inflation_annual_cpi', 'exch_usd']]
features = features.fillna(features.mean()).values # replace the null value with the mean
target = df['banking_crisis'].map({'crisis': 1, 'no_crisis': -1}).values

'''scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)'''

# Convert to PyTorch tensors
train_input = torch.tensor(features, dtype=torch.float32).to(device)
train_label = torch.tensor(target, dtype=torch.float32).to(device)

# Create dataset dictionary similar to the original example
dataset = {
    'train_input': train_input,
    'train_label': train_label,
    'test_input': train_input.clone(),  # Use the training data as the test data
    'test_label': train_label.clone()
}

# The shapes will show the dimensions of your data
dataset['train_input'].shape, dataset['train_label'].shape
# Out:
# (torch.Size([1059, 2]), torch.Size([1059]))

# %%
# plot KAN at initialization
model(dataset['train_input']);
model.plot()

# %%
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
model.plot()
# Out:
# | train_loss: 8.70e+00 | test_loss: 8.70e+00 | reg: 4.58e+01 | : 100%|█| 50/50 [00:16<00:00,  3.11it
# saving model version 0.1

# %%
model = model.prune()
model.plot()
# train again after pruning
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
# Out:
# saving model version 0.2
# | train_loss: 9.75e-01 | test_loss: 9.75e-01 | reg: 3.48e+01 | : 100%|█| 50/50 [00:13<00:00,  3.73it
# saving model version 0.3
# {'train_loss': [array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32)],
#  'test_loss': [array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.97544837, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754484, dtype=float32),
#   array(0.9754483, dtype=float32),
#   array(0.97544837, dtype=float32)],
#  'reg': [array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32),
#   array(34.816406, dtype=float32)]}

# %%
model.plot()
# Out:
# saving model version 0.4

# %%
# train again after pruning
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
model = model.refine(5)
model.plot()
# Out:
# | train_loss: 9.75e-01 | test_loss: 9.75e-01 | reg: 3.48e+01 | : 100%|█| 50/50 [00:20<00:00,  2.42it
# saving model version 0.5
# saving model version 0.6
# saving model version 0.7

# %%
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
model = model.refine(10)
model.plot()
# Out:
# | train_loss: 9.79e-01 | test_loss: 9.79e-01 | reg: 3.48e+01 | : 100%|█| 50/50 [00:23<00:00,  2.14it
# saving model version 0.8
# saving model version 0.9

# %%
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
model = model.refine(25)
model.plot()
# Out:
# | train_loss: 9.79e-01 | test_loss: 9.79e-01 | reg: 3.48e+01 | : 100%|█| 50/50 [00:22<00:00,  2.22it
# saving model version 0.10
# saving model version 0.11

# %%
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
model.plot()
# Out:
# | train_loss: 9.79e-01 | test_loss: 9.79e-01 | reg: 3.48e+01 | : 100%|█| 50/50 [00:22<00:00,  2.22it
# saving model version 0.10
# saving model version 0.11

# %%
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
model.plot()
# Out:
# | train_loss: 9.79e-01 | test_loss: 9.79e-01 | reg: 3.48e+01 | : 100%|█| 50/50 [00:22<00:00,  2.22it
# saving model version 0.10
# saving model version 0.11

# %%
lib = SYMBOLIC_LIB  # candidate libraries from SYMBOLIC_LIB
model.auto_symbolic(lib=lib)  # automatically select the best sign function
formula = model.symbolic_formula()[0][0]
nsimplify(formula)
# Out:
# fixing (0,0,0) with x, r2=1.0000004768371582, c=1
# fixing (0,0,1) with x, r2=1.0000007152557373, c=1
# fixing (0,0,2) with x, r2=1.0000004768371582, c=1
# fixing (0,0,3) with x, r2=1.0000014305114746, c=1
# fixing (0,1,0) with 0
# fixing (0,1,1) with 0
# fixing (0,1,2) with 0
# fixing (0,1,3) with 0
# fixing (1,0,0) with x, r2=1.0000007152557373, c=1
# fixing (1,1,0) with x, r2=1.0000004768371582, c=1
# fixing (1,2,0) with x, r2=1.000001072883606, c=1
# fixing (1,3,0) with x, r2=1.0000007152557373, c=1
# saving model version 0.12
# 405502136979763*x_1/1000000000000000000000 - 369180905646397/10000000000000000

# %%
ex_round(formula, 4)
# Out:
# -0.0369
