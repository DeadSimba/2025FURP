# %%
from kan import *

# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = KAN(width=[2,5,1], grid=5, k=3, seed=0,device=device)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %% [markdown]
# #### Data source: https://www.kaggle.com/datasets/nikunjhemani/freddie-macs-dataset-pre-processed/code
# #### Feature selection: https://www.kaggle.com/code/missionjee/feature-selection

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('FreddieMac.csv')
df['LTV_range'] = df['LTV_range'].map({'Low': 1, 'Medium': 2, 'High':3})

# Select features and target variable
'''features = df[['Repay_range', 'LTV_range', 'FirstTimeHomebuyer', 'NumBorrowers','MonthsInRepayment', 'OrigUPB', 
               'OrigInterestRate', 'MIP', 'Maturity_Year', 'FirstPayment_Year','MSA', 'DTI']].values'''    
features = df[['Repay_range', 'LTV_range', 'FirstTimeHomebuyer', 'NumBorrowers']].values     
    
# features = features.fillna(features.mean()).values # replace the null value with the mean
target = df['Credit_range'].map({'Poor': 0, 'Fair': 1, 'Good': 2}).values

'''scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)'''

# Convert to PyTorch tensors
train_input = torch.tensor(features, dtype=torch.float32).to(device)
train_label = torch.tensor(target, dtype=torch.float32).to(device)

# Create dataset dictionary similar to the original example
dataset = {
    'train_input': train_input,
    'train_label': train_label,
    'test_input': train_input.clone(),  # Use the training data as the test data
    'test_label': train_label.clone()
}
# The shapes will show the dimensions of your data
dataset['train_input'].shape, dataset['train_label'].shape
# Out:
# (torch.Size([148938, 4]), torch.Size([148938]))

# %%
dataset = {
    'train_input': dataset['train_input'][:3000],
    'train_label': dataset['train_label'][:3000],
    'test_input': dataset['test_input'][:3000],
    'test_label': dataset['test_label'][:3000]
}

# plot KAN at initialization
model(dataset['train_input']);
model.plot();
# model.plot(beta=100,sample=True)

# %%
model.fit(dataset, opt="LBFGS", steps=50, lamb=0.001);
model.plot()
# Out:
# | train_loss: 5.32e-01 | test_loss: 5.32e-01 | reg: 5.41e+00 | : 100%|█| 50/50 [01:57<00:00,  2.35s/
# saving model version 0.1

# %%
model = model.prune()
model.plot()
# train again after pruning
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
# Out:
# saving model version 0.2
# | train_loss: 5.31e-01 | test_loss: 5.31e-01 | reg: 4.96e+00 | : 100%|█| 50/50 [01:12<00:00,  1.45s/
# saving model version 0.3
# {'train_loss': [array(0.53826237, dtype=float32),
#   array(0.53144866, dtype=float32),
#   array(0.5310048, dtype=float32),
#   array(0.5308978, dtype=float32),
#   array(0.5307962, dtype=float32),
#   array(0.530802, dtype=float32),
#   array(0.5308183, dtype=float32),
#   array(0.5307834, dtype=float32),
#   array(0.5307561, dtype=float32),
#   array(0.53075993, dtype=float32),
#   array(0.53075767, dtype=float32),
#   array(0.5307567, dtype=float32),
#   array(0.53075635, dtype=float32),
#   array(0.5307561, dtype=float32),
#   array(0.5307559, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.53075606, dtype=float32),
#   array(0.53075606, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.53075606, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32)],
#  'test_loss': [array(0.53826237, dtype=float32),
#   array(0.53144866, dtype=float32),
#   array(0.53100485, dtype=float32),
#   array(0.5308978, dtype=float32),
#   array(0.5307962, dtype=float32),
#   array(0.53080195, dtype=float32),
#   array(0.5308183, dtype=float32),
#   array(0.5307834, dtype=float32),
#   array(0.5307561, dtype=float32),
#   array(0.53075993, dtype=float32),
#   array(0.53075767, dtype=float32),
#   array(0.5307567, dtype=float32),
#   array(0.53075635, dtype=float32),
#   array(0.5307561, dtype=float32),
#   array(0.5307559, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.53075606, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.53075606, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.530756, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32),
#   array(0.53075594, dtype=float32)],
#  'reg': [array(23.507515, dtype=float32),
#   array(18.861347, dtype=float32),
#   array(15.108006, dtype=float32),
#   array(13.654668, dtype=float32),
#   array(10.690868, dtype=float32),
#   array(9.79517, dtype=float32),
#   array(9.440813, dtype=float32),
#   array(8.898297, dtype=float32),
#   array(7.1997557, dtype=float32),
#   array(6.4455786, dtype=float32),
#   array(6.032439, dtype=float32),
#   array(5.705945, dtype=float32),
#   array(5.497858, dtype=float32),
#   array(5.2847595, dtype=float32),
#   array(5.0674577, dtype=float32),
#   array(5.00598, dtype=float32),
#   array(4.973302, dtype=float32),
#   array(4.9719434, dtype=float32),
#   array(4.971899, dtype=float32),
#   array(4.967187, dtype=float32),
#   array(4.967146, dtype=float32),
#   array(4.9670553, dtype=float32),
#   array(4.967056, dtype=float32),
#   array(4.9669957, dtype=float32),
#   array(4.9669533, dtype=float32),
#   array(4.9669533, dtype=float32),
#   array(4.966901, dtype=float32),
#   array(4.966841, dtype=float32),
#   array(4.9667144, dtype=float32),
#   array(4.960989, dtype=float32),
#   array(4.9609537, dtype=float32),
#   array(4.9609537, dtype=float32),
#   array(4.9609494, dtype=float32),
#   array(4.960924, dtype=float32),
#   array(4.959294, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32),
#   array(4.9592347, dtype=float32)]}

# %%
model = model.prune()
model.plot()
# Out:
# saving model version 0.4

# %%
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
model = model.prune()
model.plot()
model = model.refine(10)
# Out:
# | train_loss: 5.31e-01 | test_loss: 5.31e-01 | reg: 4.93e+00 | : 100%|█| 50/50 [00:41<00:00,  1.20it
# saving model version 0.5
# saving model version 0.6
# saving model version 0.7

# %%
# model.fit(dataset, opt="LBFGS", steps=50,lamb=0.001);
model.fit(
    dataset=dataset,
    opt="LBFGS",
    steps=50,
    lamb=0.001, 
    lamb_entropy=10.,
    lr=0.001,
    update_grid=False)
model = model.prune()
model.plot()
# Out:
# | train_loss: 5.33e-01 | test_loss: 5.33e-01 | reg: 1.32e+01 | : 100%|█| 50/50 [00:36<00:00,  1.35it
# saving model version 0.8
# saving model version 0.9

# %%
lib = SYMBOLIC_LIB  # candidate libraries from SYMBOLIC_LIB
model.auto_symbolic(lib=lib)  # automatically select the best sign function
formula = model.symbolic_formula()[0][0]
ex_round(formula, 4)
# nsimplify(ex_round(formula, 4))
# Out:
# fixing (0,0,0) with sin, r2=1.0000004768371582, c=2
# fixing (0,1,0) with exp, r2=1.000001072883606, c=2
# fixing (1,0,0) with cos, r2=0.9991599321365356, c=2
# saving model version 0.10
# 0.2282 - 0.1741*cos(3.6982*exp(0.107*x_2) + 1.16*sin(5.9986*x_1 - 8.3986) - 5.8017)
